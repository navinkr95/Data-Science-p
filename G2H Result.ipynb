# %% [markdown]
# # Sevya mocktest 1

# %%
import gspread
import pandas as pd
Cred_FILE = r'D:\Sevya\gametohire-2a9f43b5aa49.json'
gc=gspread.service_account(Cred_FILE)
gc
database=gc.open("G2h Automation")
database 
wks=database.worksheet("mock 1")
wks
import pandas as pd
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2hdb')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 3'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)



lst=df.values.tolist()



from googleapiclient.discovery import build


from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE ='D:\Sevya\gametohire-2a9f43b5aa49.json'
 
    
creds=None
creds= service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)


SAMPLE_SPREADSHEET_ID = '1ESEecZyxI1Km4UQ_YAugkSYYziqZRYxYh632g0nkwQc'


service = build('sheets','v4',credentials=creds)
sheet = service.spreadsheets()




# To write data to Gsheet by using python

word="G2H TBD"
cell=wks.find(word)
c="D"+str(cell.row+1)

request= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
            range="mock 1!"+(c), valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS", body={"values":lst}).execute()
word="Not Qualified"
cell=wks.find(word)
e="AA"+str(cell.row+1)
word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "mock 1!"+c1+":"+e).execute()
values = result.get('values', [])

data=pd.DataFrame(values)
values = result.get('values', [])

data=pd.DataFrame(values)
data[0]="inprogress"
df=data[data[24]>=data[25]]
data1=pd.DataFrame(values)
data1[0]="Failed"
df1=data1[data1[24]<data1[25]]

lst=df.values.tolist()
lst1=df1.values.tolist()
word="Not Qualified"
cell=wks.find(word)
e1='AA'+str(cell.row-1)
    
request = sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 1!"+(c)+":"+(e1)).execute()

word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 1!"+c1, valueInputOption="USER_ENTERED",body={"values":lst1}).execute()
word="L1"
cell=wks.find(word)
d="A"+str(cell.row+1)    

request1= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 1!"+d, valueInputOption="USER_ENTERED",
            insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
word="G2H TBD"
cell=wks.find(word)
c_end="AA"+str(cell.row-1)





# To read data
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "mock 1!"+d+":"+c_end).execute()
values = result.get('values', [])
data=pd.DataFrame(values)

df=data[data[0]=="Selected in L1"]
df1=data[data[0]!="Selected in L1"]
lst=df.values.tolist()
lst1=df1.values.tolist()
a=1
b=1
while(True):
    while(True):
        x=request1["updates"]["updatedRange"]
       
        

        try:
            word="L2"
            cell1=wks.find(word)
            L2="A"+str(cell1.row+1)

            word="L1"
            cell=wks.find(word)
            L1_end="AA"+str(cell.row-1)
            result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=x).execute()
            values = result.get('values', [])
            data=pd.DataFrame(values)
            df=data[data[0]=="Selected in L1"]
            df[0]="L2 in process"
            lst=df.values.tolist()
            df1=data[data[0]=="Unselected in L1"]
            df1[0]="falied in L1"
            lst1=df1.values.tolist()
        except:
            pass

        l=lst+lst1
        if(l!=[]):
            for i in l:
                try:
                    if(i[0]=="L2 in process"):
                        word="Selected in L1"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)

                        word="L2"
                        cell=wks.find(word)
                        L2="A"+str(cell.row+1)
                        request2= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                                        range="mock 1!"+L2, valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
                        print(request)
                except:
                    pass
                    
                    
                else:
                    try:
                        word="Unselected in L1"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)





                        word="Not Qualified"
                        cell=wks.find(word)
                        e2='A'+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                              range="mock 1!"+e2,valueInputOption="USER_ENTERED",
                              insertDataOption="INSERT_ROWS",body={"values":lst1}).execute()


                        break
                    except:
                        pass
        
                
       
        else: 
            try:
                
                result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                            range= "mock 1!"+L2+":"+c_end).execute()
                values = result.get('values', [])
                data2=pd.DataFrame(values)
            

                df1=data2[data2[0]=="Selected in L2"]
                df1[0]="inprogress"
                df2=data2[data2[0]=="Unselected in L2"]
                df2[0]="failed in L2"
            except:
                pass

            lst2=df1.values.tolist()
            lst3=df2.values.tolist()
            l1=lst2+lst3

            if(l1!=[]):
                for i in l1:
                    if(i[0]=="inprogress"):
                        

                        try:
                            
                            word="L3"
                            cell=wks.find(word)
                            L3="A"+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 1!"+L3, valueInputOption="USER_ENTERED",
                                   insertDataOption="INSERT_ROWS",body={"values":lst2}).execute()
                            word="Selected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)
                            continue
                        except:
                            pass
                    else:
                        try:
                            
                            word="Unselected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)





                            word="Not Qualified"
                            cell=wks.find(word)
                            e2='A'+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 1!"+e2,valueInputOption="USER_ENTERED",
                                  insertDataOption="INSERT_ROWS",body={"values":lst3}).execute()

                            break
                        except:
                            pass

                       
                    
            
                   
            break
            
    if (len(l1)==len(data2) and len(l)==len(data) ):
        break
# Out:
# <ipython-input-2-741db0613153>:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[0]="L2 in process"
# {'spreadsheetId': '1ESEecZyxI1Km4UQ_YAugkSYYziqZRYxYh632g0nkwQc', 'updates': {'spreadsheetId': '1ESEecZyxI1Km4UQ_YAugkSYYziqZRYxYh632g0nkwQc', 'updatedRange': "'mock 1'!A15:AA21", 'updatedRows': 7, 'updatedColumns': 27, 'updatedCells': 189}}

# %%
import pytest
pytest.mark.number
def x():
    assert 2+3==5

# %%
import gspread
import pandas as pd
Cred_FILE = r'C:\Users\User\Downloads\g2h-project-b4a504461160.json'
gc=gspread.service_account(Cred_FILE)
gc
database=gc.open("Untitled spreadsheet")
database 
wks=database.worksheet("Sheet14")
wks
import pandas as pd
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2h4')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 3'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)



lst=df.values.tolist()



from googleapiclient.discovery import build


from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE = r'C:\Users\User\Downloads\g2h-project-b4a504461160.json'
 
    
creds=None
creds= service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)


SAMPLE_SPREADSHEET_ID = '1tRowKTnP3eMXfF4bXmGofqjkI6QW11qD2eI5Zk4Z9e4'


service = build('sheets','v4',credentials=creds)
sheet = service.spreadsheets()

# To read data from GSheet to python
# result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
#                                     range= "Test!A2:C9").execute()
# values = result.get('values', [])
# print(values)


# To write data to Gsheet by using python

word="G2H TBD"
cell=wks.find(word)
c="D"+str(cell.row+1)

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range="sheet14!"+(c), valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS", body={"values":lst}).execute()
word="end"
cell=wks.find(word)
e="AA"+str(cell.row+1)
word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "sheet14!"+c1+":"+e).execute()
values = result.get('values', [])

data=pd.DataFrame(values)
values = result.get('values', [])

data=pd.DataFrame(values)
data[0]="inprogress"
df=data[data[24]>=data[25]]
data1=pd.DataFrame(values)
data1[0]="Failed"
df1=data1[data1[24]<data1[25]]

lst=df.values.tolist()
lst1=df1.values.tolist()
word="end"
cell=wks.find(word)
e1='AA'+str(cell.row-1)
    
request = sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="sheet14!"+(c)+":"+(e1)).execute()

word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="sheet14!"+c1, valueInputOption="USER_ENTERED",body={"values":lst1}).execute()
word="L1"
cell=wks.find(word)
d="A"+str(cell.row+1)    

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="sheet14!"+d, valueInputOption="USER_ENTERED",
            insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
word="G2H TBD"
cell=wks.find(word)
c_end="AA"+str(cell.row-1)


# To read data
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "sheet14!"+d+":"+c_end).execute()
values = result.get('values', [])
data=pd.DataFrame(values)

df=data[data[0]=="Selected"]
df1=data[data[0]!="Selected"]
lst=df.values.tolist()
lst1=df1.values.tolist()
a=1
b=1
word="L1"
cell=wks.find(word)
d="A"+str(cell.row+1)
        
word="G2H TBD"
cell=wks.find(word)
c_end="AA"+str(cell.row-1)

word="L3"
cell=wks.find(word)
L3="A"+str(cell.row+1)

while(True):
       
        try:
            result1 = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                        range= "sheet14!"+d+":"+c_end).execute()
            values = result1.get('values', [])
            data=pd.DataFrame(values)
            df=data[data[0]=="Selected"]
            df[0]="L2 in process"
            lst=df.values.tolist()
            df1=data[data[0]=="Unselected"]
            df1[0]="Unselected in L1"
            lst1=df1.values.tolist()
        except:
            pass
        l=lst+lst1
        if(l!=[]):
            for i in l:
                try:
                    
                    if(i[0]=="L2 in process"):
                        word="Selected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)
                        word="L2"
                        cell=wks.find(word)
                        L2="A"+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                                        range="sheet14!"+L2, valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
                        print(request)

                    else:
                        word="Unselected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)





                        word="Not Qualified"
                        cell=wks.find(word)
                        e2='A'+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                              range="sheet14!"+e2,valueInputOption="USER_ENTERED",
                              insertDataOption="INSERT_ROWS",body={"values":lst1}).execute()



                        break
                except:
                    pass

                
       
        try: 
            word="L2"
            cell1=wks.find(word)
            L2="A"+str(cell1.row+1)

            word="L1"
            cell=wks.find(word)
            L1_end="AA"+str(cell.row-1)
            result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                            range= "sheet14!"+L2+":"+L1_end).execute()
            values = result.get('values', [])
            data2=pd.DataFrame(values)

            df1=data2[data2[0]=="Selected in L2"]
            df1[0]="inprogress"
            df2=data2[data2[0]=="Unselected in L2"]
            df2[0]="failed in L2"

            lst2=df1.values.tolist()
            lst3=df2.values.tolist()
        except:
            pass
        l1=lst2+lst3

        if(l1!=[]):
            for i in l1:
                try:
                    if(i[0]=="inprogress"):


                        word="Selected in L2"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)



                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="sheet14!"+L3, valueInputOption="USER_ENTERED",
                                   insertDataOption="INSERT_ROWS",body={"values":lst2}).execute()



                    if(i[0]=="failed in L2"):
                        word="Unselected in L2"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)





                        word="end"
                        cell=wks.find(word)
                        e2='A'+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range="sheet14!"+e2,valueInputOption="USER_ENTERED",
                                  insertDataOption="INSERT_ROWS",body={"values":lst3}).execute()

                        break
                except:
                    pass

# %%
 result1 = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "sheet14!"+d+":"+c_end).execute()
len(result1)

# %%
request1["updates"]["updatedRange"]

# %%
request2["updates"]["updatedRange"]

# %% [markdown]
# # Sevya mocktest 2

# %%
import gspread
import pandas as pd
Cred_FILE = r'D:\Sevya\gametohire-2a9f43b5aa49.json'
gc=gspread.service_account(Cred_FILE)
gc
database=gc.open("G2h Automation")
database 
wks=database.worksheet("mock 2")
wks
import pandas as pd
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2hdb')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 2'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)



lst=df.values.tolist()



from googleapiclient.discovery import build


from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE ='D:\Sevya\gametohire-2a9f43b5aa49.json'
 
    
creds=None
creds= service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)


SAMPLE_SPREADSHEET_ID = '1ESEecZyxI1Km4UQ_YAugkSYYziqZRYxYh632g0nkwQc'


service = build('sheets','v4',credentials=creds)
sheet = service.spreadsheets()




# To write data to Gsheet by using python

word="G2H TBD"
cell=wks.find(word)
c="D"+str(cell.row+1)

request= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
            range="mock 2!"+(c), valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS", body={"values":lst}).execute()
word="Not Qualified"
cell=wks.find(word)
e="AA"+str(cell.row+1)
word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "mock 2!"+c1+":"+e).execute()
values = result.get('values', [])

data=pd.DataFrame(values)
values = result.get('values', [])

data=pd.DataFrame(values)
data[0]="inprogress"
df=data[data[24]>=data[25]]
data1=pd.DataFrame(values)
data1[0]="Failed"
df1=data1[data1[24]<data1[25]]

lst=df.values.tolist()
lst1=df1.values.tolist()
word="Not Qualified"
cell=wks.find(word)
e1='AA'+str(cell.row-1)
    
request = sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 2!"+(c)+":"+(e1)).execute()

word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 2!"+c1, valueInputOption="USER_ENTERED",body={"values":lst1}).execute()
word="L1"
cell=wks.find(word)
d="A"+str(cell.row+1)    

request1= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 2!"+d, valueInputOption="USER_ENTERED",
            insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
word="G2H TBD"
cell=wks.find(word)
c_end="AA"+str(cell.row-1)





# To read data
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "mock 2!"+d+":"+c_end).execute()
values = result.get('values', [])
data=pd.DataFrame(values)

df=data[data[0]=="Selected"]
df1=data[data[0]!="Selected"]
lst=df.values.tolist()
lst1=df1.values.tolist()
a=1
b=1
while(True):
    while(True):
        x=request1["updates"]["updatedRange"]
       
        

        try:
            word="L2"
            cell1=wks.find(word)
            L2="A"+str(cell1.row+1)

            word="L1"
            cell=wks.find(word)
            L1_end="AA"+str(cell.row-1)
            result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=x).execute()
            values = result.get('values', [])
            data=pd.DataFrame(values)
            df=data[data[0]=="Selected"]
            df[0]="L2 in process"
            lst=df.values.tolist()
            df1=data[data[0]=="Unselected"]
            df1[0]="falied in L1"
            lst1=df1.values.tolist()
        except:
            pass

        l=lst+lst1
        if(l!=[]):
            for i in l:
                try:
                    if(i[0]=="L2 in process"):
                        word="Selected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)

                        word="L2"
                        cell=wks.find(word)
                        L2="A"+str(cell.row+1)
                        request2= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                            range="mock 2!"+L2, valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
                        print(request)
                except:
                    pass
                    
                    
                else:
                    try:
                        word="Unselected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)





                        word="Not Qualified"
                        cell=wks.find(word)
                        e2='A'+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                              range="mock 2!"+e2,valueInputOption="USER_ENTERED",
                              insertDataOption="INSERT_ROWS",body={"values":lst1}).execute()


                        break
                    except:
                        pass
        
                
       
        else: 
            try:
                
                result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                            range= "mock 2!"+L2+":"+c_end).execute()
                values = result.get('values', [])
                data2=pd.DataFrame(values)
            

                df1=data2[data2[0]=="Selected in L2"]
                df1[0]="inprogress"
                df2=data2[data2[0]=="Unselected in L2"]
                df2[0]="failed in L2"
            except:
                pass

            lst2=df1.values.tolist()
            lst3=df2.values.tolist()
            l1=lst2+lst3

            if(l1!=[]):
                for i in l1:
                    if(i[0]=="inprogress"):
                        

                        try:
                            
                            word="L3"
                            cell=wks.find(word)
                            L3="A"+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 2!"+L3, valueInputOption="USER_ENTERED",
                                   insertDataOption="INSERT_ROWS",body={"values":lst2}).execute()
                            word="Selected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)
                            continue
                        except:
                            pass
                    else:
                        try:
                            
                            word="Unselected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)





                            word="Not Qualified"
                            cell=wks.find(word)
                            e2='A'+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 2!"+e2,valueInputOption="USER_ENTERED",
                                  insertDataOption="INSERT_ROWS",body={"values":lst3}).execute()

                            break
                        except:
                            pass

                       
                    
            
                   
            break
            
    if (len(l1)==len(data2) and len(l)==len(data) ):
        break

# %% [markdown]
# # SEvya Mocktest 3

# %%
import gspread
import pandas as pd
Cred_FILE = r'D:\Sevya\gametohire-2a9f43b5aa49.json'
gc=gspread.service_account(Cred_FILE)
gc
database=gc.open("G2h Automation")
database 
wks=database.worksheet("mock 3")
wks
import pandas as pd
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2hdb')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 1'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)



lst=df.values.tolist()



from googleapiclient.discovery import build


from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE ='D:\Sevya\gametohire-2a9f43b5aa49.json'
 
    
creds=None
creds= service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)


SAMPLE_SPREADSHEET_ID = '1ESEecZyxI1Km4UQ_YAugkSYYziqZRYxYh632g0nkwQc'


service = build('sheets','v4',credentials=creds)
sheet = service.spreadsheets()




# To write data to Gsheet by using python

word="G2H TBD"
cell=wks.find(word)
c="D"+str(cell.row+1)

request= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
            range="mock 3!"+(c), valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS", body={"values":lst}).execute()
word="Not Qualified"
cell=wks.find(word)
e="AA"+str(cell.row+1)
word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range= "mock 3!"+c1+":"+e).execute()
values = result.get('values', [])

data=pd.DataFrame(values)
values = result.get('values', [])

data=pd.DataFrame(values)
data[0]="inprogress"
df=data[data[24]>=data[25]]
data1=pd.DataFrame(values)
data1[0]="Failed"
df1=data1[data1[24]<data1[25]]

lst=df.values.tolist()
lst1=df1.values.tolist()
word="Not Qualified"
cell=wks.find(word)
e1='AA'+str(cell.row-1)
    
request = sheet.values().clear(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 3!"+(c)+":"+(e1)).execute()

word="G2H TBD"
cell=wks.find(word)
c1="A"+str(cell.row+1)

request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 3!"+c1, valueInputOption="USER_ENTERED",body={"values":lst1}).execute()
word="L1"
cell=wks.find(word)
d="A"+str(cell.row+1)    

request1= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range="mock 3!"+d, valueInputOption="USER_ENTERED",
            insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
word="G2H TBD"
cell=wks.find(word)
c_end="AA"+str(cell.row-1)





# To read data

while(True):
    while(True):
        x=request1["updates"]["updatedRange"]
       
        

        try:
            word="L2"
            cell1=wks.find(word)
            L2="A"+str(cell1.row+1)

            word="L1"
            cell=wks.find(word)
            L1_end="AA"+str(cell.row-1)
            result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=x).execute()
            values = result.get('values', [])
            data=pd.DataFrame(values)
            df=data[data[0]=="Selected"]
            df[0]="L2 in process"
            lst=df.values.tolist()
            df1=data[data[0]=="Unselected"]
            df1[0]="falied in L1"
            lst1=df1.values.tolist()
        except:
            pass

        l=lst+lst1
        if(l!=[]):
            for i in l:
                try:
                    if(i[0]=="L2 in process"):
                        word="Selected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)

                        word="L2"
                        cell=wks.find(word)
                        L2="A"+str(cell.row+1)
                        request2= sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                                        range="mock 3!"+L2, valueInputOption="USER_ENTERED",insertDataOption="INSERT_ROWS",body={"values":lst}).execute()
                        print(request)
                except:
                    pass
                    
                    
                else:
                    try:
                        word="Unselected"
                        x3=wks.find(word)
                        x4=x3.row
                        wks.delete_rows(x4)





                        word="Not Qualified"
                        cell=wks.find(word)
                        e2='A'+str(cell.row+1)
                        request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                              range="mock 3!"+e2,valueInputOption="USER_ENTERED",
                              insertDataOption="INSERT_ROWS",body={"values":lst1}).execute()


                        break
                    except:
                        pass
        
                
       
        else: 
            try:
                
                result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                            range= "mock 3!"+L2+":"+c_end).execute()
                values = result.get('values', [])
                data2=pd.DataFrame(values)
            

                df1=data2[data2[0]=="Selected in L2"]
                df1[0]="inprogress"
                df2=data2[data2[0]=="Unselected in L2"]
                df2[0]="failed in L2"
            except:
                pass

            lst2=df1.values.tolist()
            lst3=df2.values.tolist()
            l1=lst2+lst3

            if(l1!=[]):
                for i in l1:
                    if(i[0]=="inprogress"):
                        

                        try:
                            
                            word="L3"
                            cell=wks.find(word)
                            L3="A"+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 3!"+L3, valueInputOption="USER_ENTERED",
                                   insertDataOption="INSERT_ROWS",body={"values":lst2}).execute()
                            word="Selected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)
                            continue
                        except:
                            pass
                    else:
                        try:
                            
                            word="Unselected in L2"
                            x3=wks.find(word)
                            x4=x3.row
                            wks.delete_rows(x4)





                            word="Not Qualified"
                            cell=wks.find(word)
                            e2='A'+str(cell.row+1)
                            request = sheet.values().append(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range="mock 3!"+e2,valueInputOption="USER_ENTERED",
                                  insertDataOption="INSERT_ROWS",body={"values":lst3}).execute()

                            break
                        except:
                            pass

                       
                    
            
                   
            break
            
    if (len(l1)==len(data2) and len(l)==len(data) ):
        break

# %%
li=['A']
li.extend('BCD')
print(li)

# %%
def test_m22():
    name="navin"
    assert name.upper()== "NAIN"

# %%
test_m22()

# %%
pytest -v

# %%
import pandas as pd
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2hdb')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 3'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)

# %%
df

# %%
print(data)

# %%
import pymysql
con=pymysql.connect(host='127.0.0.1',user='root',password='root123',database='g2hdb')
cur=con.cursor()
qry='''select firstName," "," "," ",dateOfBirth," "," "," "," "," "," "," "," ",mobile,email,user.experience," "," "," "," "," ",
 score,cutoffscore,j.name from
 user inner join userprogresssummary as u on user.id=u.userid  
 inner join jobs as j on j.id=u.jobId
 inner join userprogressdetails as up on u.id=up.userProgressSummaryId 
 inner join questchallengemapper as q on up.questChallengeMapperId=q.id where j.name='Sevya Mock Test 3'
 and day(user.createdDate)=26 and month(user.createdDate)=10 and year(user.createdDate)=2022;
 '''

cur.execute(qry)
data=cur.fetchall()
con.close()
df=pd.DataFrame(data)
